# %% [markdown]
# #### A) KNN-nearest neighbor

# %%
import numpy as np
from collections import Counter
# Should use the `find_k_nearest_neighbors` function below.
def predict_label(examples, features, k, label_key="is_intrusive"):
    dist = {}
    labels = {}
    for i in examples:
        dist[i] = np.sum([(examples[i]['feature'][j] - features[j])**2 for j in range(len(features))])
        labels[i] = examples[i][label_key]
    dist = {k:v for k,v in sorted(dist.items(),key=lambda x:x[1])}
    knn = list(dist.keys())[0:k]
    l = [labels[k] for k in knn]
    c = dict(Counter(l))
    c = {k:v for k,v in sorted(c.items(),key=lambda x:x[1],reverse = True)}
    return list(c.keys())[0]    


def find_k_nearest_neighbors(examples, features, k):
    dist = {}
    for i in examples:
        dist[i] = np.sum([(examples[i]['feature'][j] - features[j])**2 for j in range(len(features))])
    dist = {k:v for k,v in sorted(dist.items(),key=lambda x:x[1])}
    knn = list(dist.keys())[0:k]
    return knn

# %%
d = {'pid_1':{'feature':[1.2,1.3], 'label':0},'pid_4':{'feature':[2.42,1.99], 'label':1},'pid_3':{'feature':[2.4,3.3], 'label':1},'pid_2':{'feature':[1.52,1.36], 'label':0},'pid_5':{'feature':[1.02,1.73],'label':0}}

# Path: ML_Algorithm_fundamental/ML_algo.ipynb
feature = [2.4,3.5]
find_k_nearest_neighbors(d, feature,1)
# Out:
# ['pid_3']

# %% [markdown]
# ### B) KMEANs Clustering

# %%
import random
import numpy as np

class Centroid:
    def __init__(self, location):
        self.location = location
        self.closest_users = set()


def get_k_means(user_feature_map, num_features_per_user, k):
    # Don't change the following two lines of code.
    random.seed(42)
    # Gets the inital users, to be used as centroids.
    inital_centroid_users = random.sample(sorted(list(user_feature_map.keys())), k)
    d1 = list(user_feature_map.values())
    centroid_feat = np.array([user_feature_map[c] for c in inital_centroid_users])
    for j in range(200):
        assign = []
        for i in user_feature_map:
            c = np.argmin(np.sum(abs(np.array(user_feature_map[i]).reshape((1,num_features_per_user))-centroid_feat),axis=1))
            assign.append(c)   
        center = []
        for i in range(len(inital_centroid_users)):
            ce = np.mean([d1[x] for x in range(len(user_feature_map)) if assign[x]==i],axis=0)
            center.append(list(ce))
            centroid_feat = np.array(center)
    return [list(centroid_feat[i]) for i in range(k)]

d = {'pid_1':[1.2,1.3],'pid_2':[2.42,1.99],'pid_3':[2.4,3.3],'pid_2':[1.52,1.36],'pid_5':[1.02,1.73],'pid_6':[2.52,2.36],'pid_7':[1.12,1.93],'pid_8':[2.42,1.96],'pid_9':[1.22,1.83],'pid_10':[2.52,1.96],'pid_11':[1.05,1.71]}

# %%
#kmeans

from sklearn.datasets import make_blobs
X_train, true_labels = make_blobs(n_samples=100, centers=centers, random_state=42)
X_train = dict(zip(['pid_'+str(i) for i in range(100)],X_train))
get_k_means(X_train, 2, k=1)
# Out:
# [[-2.4476715310291493, 3.1452113041203607]]

# %% [markdown]
# ### C) Multinomial Naive Bayes- text classification

# %%
class NB_multinomial:
    def __init__(self,data,alpha):
        self.alpha = 1
        self.data = data
        self.train()
    def train(self):
        self.priors = {}
        total = np.sum([len(self.data[i]) for i in self.data])
        for tag in self.data:
            self.priors[tag] = len(self.data[tag])/total
        self.count_word_per_tag = defaultdict(lambda:{tag:0 for tag in self.data})
        self.total_word_count_tag = defaultdict(int)
        for tag in self.data:
            for article in self.data[tag]:
                for word in article:
                    self.count_word_per_tag[word][tag] += 1
                    self.total_word_count_tag[tag] +=1
        self.word_liklihood_tag = defaultdict(lambda:{tag:0.5 for tag in self.data})
        for word, tag_map in self.count_word_per_tag.items():
            for tag in tag_map:
                self.word_liklihood_tag[word][tag] = (self.count_word_per_tag[word][tag] + 1 * self.alpha)/(self.total_word_count_tag[tag] + 2 * self.alpha)
        return self
    def predict(self,article):
        prediction = {}
        for tag in self.data:
            numerator = np.log(self.priors[tag])
            for word in article:
                numerator += np.log(self.word_liklihood_tag.get(0.5,self.word_liklihood_tag[word][tag]))
            prediction[tag] = numerator
        return prediction, max(prediction, key=prediction.get)    


data = {'sports':[['the','team','played','a','great','game'],['the','game','was','awesome'],['i','love','baseball'],['i','hate','tennis']],
        'not_sports':[['i','love','my','dog'],['my','dog','hates','me'],['the','cat','scratched','me'],['i','hate','cats']]}

# %%
nb = NB_multinomial(data,alpha=1)
t = nb.train()
nb.predict(['baseball','is','tough','game'])
# Out:
# ({'sports': -6.068425588244111, 'not_sports': -7.7458682297922685}, 'sports')

# %% [markdown]
# ### D) Recursive Partitioning and Regression Trees (RPART)

# %%
class TreeNode:
    def __init__(self, examples):
        self.examples = examples
        self.left = None
        self.right = None
        self.split_point = None

    def split(self):
        if len(self.examples) == 1:
            return
        best_split = {'feature':None,'value':None,'split_index':None,'mse':100000}    
        for feat in list(self.examples[0].keys())[:-1]:
            self.examples.sort(key = lambda example:example[feat])
            for i,_ in enumerate(self.examples[:-1]):
                feat_val = (self.examples[i][feat] + self.examples[i+1][feat])/2
                bst_mse,bst_index = self.mse_split(feat,feat_val)
                if best_split['mse'] > bst_mse:
                    best_split = {'feature':feat,'value':feat_val,'split_index':bst_index,'mse':bst_mse}
        print(best_split)
        self.split_point = best_split
        self.examples.sort(key = lambda example:example[self.split_point ['feature']])
        self.left = TreeNode(self.examples[:self.split_point['split_index']])
        # print(self.left)
        self.left.split()
        self.right = TreeNode(self.examples[self.split_point['split_index']:])
        # print(self.right)
        self.right.split()
    def mse_split(self,feat,feat_val):
        left_bpds = [example['target'] for example in self.examples if example[feat] <= feat_val]                 
        split_id = len(left_bpds)
        right_bpds = [example['target'] for example in self.examples if example[feat] > feat_val]
        if not len(left_bpds) or not len(right_bpds):
            return 10,1
        left_mean,right_mean = np.mean(left_bpds),np.mean(right_bpds)
        left_mse = np.sum([(left_bpds[j]-left_mean)**2 for j in range(len(left_bpds))])/len(left_bpds)
        right_mse = np.sum([(right_bpds[j]-right_mean)**2 for j in range(len(right_bpds))])/len(right_bpds)
        total_mse = (len(left_bpds) * left_mse + len(right_bpds) * right_mse)/(len(right_bpds) + len(left_bpds))
        return total_mse,split_id
class RegressionTree:
    def __init__(self, examples):
        self.root = TreeNode(examples)
        self.train()

    def train(self):
        self.root.split()

    def predict(self, example):
        node = self.root
        while node.left and node.right:
            if example[node.split_point['feature']] <= node.split_point['value']:
                node = node.left
            else:
                node = node.right    
        val = sum([leaf['target'] for leaf in node.examples])/len(node.examples)
        return val

# %%
#Regression tree
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing
data = pd.DataFrame(np.concatenate([fetch_california_housing()['data'],fetch_california_housing()['target'].reshape(-1,1)],axis=1), columns=['MedInc',
  'HouseAge',
  'AveRooms',
  'AveBedrms',
  'Population',
  'AveOccup',
  'Latitude',
  'Longitude',
  'target']).to_dict('records')
data = data[0:100]   

r = RegressionTree(data)
r.train()
r.predict({'MedInc': 3.8462,
 'HouseAge': 52.0,
 'AveRooms': 6.281853,
 'AveBedrms': 1.081081,
 'Population': 565.0,
 'AveOccup': 2.181467,
 'Latitude': 37.85,
 'Longitude': -122.25})
# Out:
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Longitude', 'value': -122.26, 'split_index': 91, 'mse': 0.33519456665813185}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Longitude', 'value': -122.28, 'split_index': 41, 'mse': 0.25086610973712625}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Longitude', 'value': -122.29, 'split_index': 17, 'mse': 0.055946140064562416}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Population', 'value': 921.0, 'split_index': 15, 'mse': 0.02575013137254902}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 6.227536053247874, 'split_index': 10, 'mse': 0.02221850666666667}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 3.073690544049655, 'split_index': 2, 'mse': 0.003980637499999998}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.5312000000000001, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 0.7671, 'split_index': 1, 'mse': 0.0013073571428571418}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveBedrms', 'value': 1.2288599794590893, 'split_index': 4, 'mse': 0.0006844285714285705}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'HouseAge', 'value': 50.0, 'split_index': 2, 'mse': 0.00013625000000000025}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.28875, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.2798, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'HouseAge', 'value': 48.5, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 3.93415, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'HouseAge', 'value': 35.0, 'split_index': 1, 'mse': 0.0012209499999999995}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 7.342253882685149, 'split_index': 3, 'mse': 0.00031616666666666723}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.2305, 'split_index': 2, 'mse': 2.0166666666666702e-05}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.37635, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 0.8914, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 3.4733057432577468, 'split_index': 5, 'mse': 0.023327214912280698}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 2.6540451172018518, 'split_index': 2, 'mse': 0.0029999999999999966}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 0.8371500000000001, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 2.8206485327616244, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.125, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.6261, 'split_index': 8, 'mse': 0.014397377990430628}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Latitude', 'value': 37.81, 'split_index': 2, 'mse': 0.004408666666666663}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.31595, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 4.022417099030003, 'split_index': 1, 'mse': 0.0006325333333333328}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 4.67121138996139, 'split_index': 2, 'mse': 0.00014293333333333298}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.3142, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.16145, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.55775, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.2076000000000002, 'split_index': 7, 'mse': 0.006649792207792212}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Population', 'value': 982.5, 'split_index': 4, 'mse': 0.0025432380952380954}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 4.886004437617341, 'split_index': 2, 'mse': 0.00015925000000000146}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.84945, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.8681, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.88475, 'split_index': 2, 'mse': 0.00019266666666666702}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.7252, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'HouseAge', 'value': 45.0, 'split_index': 2, 'mse': 0.0006065000000000011}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.4251, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.434, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveBedrms', 'value': 0.9423218792467483, 'split_index': 1, 'mse': 0.15941113387755101}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.80475, 'split_index': 42, 'mse': 0.10526021234207969}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 4.404344822571263, 'split_index': 27, 'mse': 0.07946613509700177}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.0532, 'split_index': 17, 'mse': 0.060041097385620926}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 0.9614, 'split_index': 3, 'mse': 0.04108071568627452}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 0.9361999999999999, 'split_index': 2, 'mse': 0.0014726666666666692}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 0.8409, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Population', 'value': 1187.0, 'split_index': 10, 'mse': 0.024469721428571428}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveBedrms', 'value': 1.2100218431454128, 'split_index': 8, 'mse': 0.012632400000000002}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.0161, 'split_index': 7, 'mse': 0.008498928571428572}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'HouseAge', 'value': 34.5, 'split_index': 2, 'mse': 0.0031813857142857114}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.4892, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 3.9237433862433866, 'split_index': 4, 'mse': 0.0007937999999999987}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.09585, 'split_index': 2, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.001, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.47085, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.5099999999999998, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Population', 'value': 2746.5, 'split_index': 3, 'mse': 0.005010666666666663}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.8822, 'split_index': 2, 'mse': 0.0014106666666666692}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.5331, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveBedrms', 'value': 1.0902870388010415, 'split_index': 5, 'mse': 0.01913956}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 3.7735290770456356, 'split_index': 2, 'mse': 0.005005300000000004}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.3418, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.1226000000000003, 'split_index': 2, 'mse': 1.6666666666662996e-07}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.109, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.3453999999999997, 'split_index': 1, 'mse': 0.0013686000000000024}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.6752000000000002, 'split_index': 3, 'mse': 0.0004086666666666673}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'HouseAge', 'value': 32.0, 'split_index': 1, 'mse': 5.40000000000001e-05}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.642, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Latitude', 'value': 37.83, 'split_index': 6, 'mse': 0.03228223703703704}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 4.704879679144385, 'split_index': 3, 'mse': 0.0004198888888888896}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.4952999999999999, 'split_index': 2, 'mse': 1.5000000000000026e-06}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.2984499999999999, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.05265, 'split_index': 2, 'mse': 2.6666666666666715e-06}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.2361, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveOccup', 'value': 2.5814333753678014, 'split_index': 7, 'mse': 0.0216009126984127}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Population', 'value': 998.0, 'split_index': 5, 'mse': 0.004689900000000001}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.53565, 'split_index': 1, 'mse': 0.0011417500000000026}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.6891499999999997, 'split_index': 3, 'mse': 0.00023716666666666672}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.2972, 'split_index': 2, 'mse': 2.0166666666667108e-05}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.8523, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.1625, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.98875, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Latitude', 'value': 37.845, 'split_index': 4, 'mse': 0.03390314285714287}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 3.24625, 'split_index': 2, 'mse': 8.900000000000016e-05}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.9234999999999998, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 3.72215, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 5.40013075647404, 'split_index': 2, 'mse': 0.0133481666666667}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 3.17275, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 5.393969916733816, 'split_index': 4, 'mse': 0.11779091111111109}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveBedrms', 'value': 0.9707789730678263, 'split_index': 1, 'mse': 0.010524499999999996}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 3.4055999999999997, 'split_index': 1, 'mse': 0.0012326666666666625}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 3.864, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 8.3133, 'split_index': 4, 'mse': 0.004089749999999999}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 6.45025, 'split_index': 2, 'mse': 0.0005221250000000018}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 4.74465, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 7.779399999999999, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Longitude', 'value': -122.26, 'split_index': 91, 'mse': 0.33519456665813185}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Longitude', 'value': -122.28, 'split_index': 41, 'mse': 0.25086610973712625}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Longitude', 'value': -122.29, 'split_index': 17, 'mse': 0.055946140064562416}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Population', 'value': 921.0, 'split_index': 15, 'mse': 0.02575013137254902}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 6.227536053247874, 'split_index': 10, 'mse': 0.02221850666666667}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 3.073690544049655, 'split_index': 2, 'mse': 0.003980637499999998}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.5312000000000001, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 0.7671, 'split_index': 1, 'mse': 0.0013073571428571418}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveBedrms', 'value': 1.2288599794590893, 'split_index': 4, 'mse': 0.0006844285714285705}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'HouseAge', 'value': 50.0, 'split_index': 2, 'mse': 0.00013625000000000025}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.28875, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.2798, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'HouseAge', 'value': 48.5, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 3.93415, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'HouseAge', 'value': 35.0, 'split_index': 1, 'mse': 0.0012209499999999995}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 7.342253882685149, 'split_index': 3, 'mse': 0.00031616666666666723}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.2305, 'split_index': 2, 'mse': 2.0166666666666702e-05}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.37635, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 0.8914, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 3.4733057432577468, 'split_index': 5, 'mse': 0.023327214912280698}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 2.6540451172018518, 'split_index': 2, 'mse': 0.0029999999999999966}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 0.8371500000000001, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 2.8206485327616244, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.125, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.6261, 'split_index': 8, 'mse': 0.014397377990430628}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Latitude', 'value': 37.81, 'split_index': 2, 'mse': 0.004408666666666663}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.31595, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 4.022417099030003, 'split_index': 1, 'mse': 0.0006325333333333328}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 4.67121138996139, 'split_index': 2, 'mse': 0.00014293333333333298}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.3142, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.16145, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.55775, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.2076000000000002, 'split_index': 7, 'mse': 0.006649792207792212}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Population', 'value': 982.5, 'split_index': 4, 'mse': 0.0025432380952380954}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 4.886004437617341, 'split_index': 2, 'mse': 0.00015925000000000146}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.84945, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.8681, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.88475, 'split_index': 2, 'mse': 0.00019266666666666702}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.7252, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'HouseAge', 'value': 45.0, 'split_index': 2, 'mse': 0.0006065000000000011}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.4251, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.434, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveBedrms', 'value': 0.9423218792467483, 'split_index': 1, 'mse': 0.15941113387755101}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.80475, 'split_index': 42, 'mse': 0.10526021234207969}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 4.404344822571263, 'split_index': 27, 'mse': 0.07946613509700177}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.0532, 'split_index': 17, 'mse': 0.060041097385620926}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 0.9614, 'split_index': 3, 'mse': 0.04108071568627452}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 0.9361999999999999, 'split_index': 2, 'mse': 0.0014726666666666692}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 0.8409, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Population', 'value': 1187.0, 'split_index': 10, 'mse': 0.024469721428571428}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveBedrms', 'value': 1.2100218431454128, 'split_index': 8, 'mse': 0.012632400000000002}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.0161, 'split_index': 7, 'mse': 0.008498928571428572}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'HouseAge', 'value': 34.5, 'split_index': 2, 'mse': 0.0031813857142857114}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.4892, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 3.9237433862433866, 'split_index': 4, 'mse': 0.0007937999999999987}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.09585, 'split_index': 2, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.001, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.47085, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.5099999999999998, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Population', 'value': 2746.5, 'split_index': 3, 'mse': 0.005010666666666663}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.8822, 'split_index': 2, 'mse': 0.0014106666666666692}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.5331, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveBedrms', 'value': 1.0902870388010415, 'split_index': 5, 'mse': 0.01913956}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 3.7735290770456356, 'split_index': 2, 'mse': 0.005005300000000004}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.3418, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.1226000000000003, 'split_index': 2, 'mse': 1.6666666666662996e-07}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.109, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.3453999999999997, 'split_index': 1, 'mse': 0.0013686000000000024}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.6752000000000002, 'split_index': 3, 'mse': 0.0004086666666666673}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'HouseAge', 'value': 32.0, 'split_index': 1, 'mse': 5.40000000000001e-05}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.642, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Latitude', 'value': 37.83, 'split_index': 6, 'mse': 0.03228223703703704}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 4.704879679144385, 'split_index': 3, 'mse': 0.0004198888888888896}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.4952999999999999, 'split_index': 2, 'mse': 1.5000000000000026e-06}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.2984499999999999, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.05265, 'split_index': 2, 'mse': 2.6666666666666715e-06}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.2361, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveOccup', 'value': 2.5814333753678014, 'split_index': 7, 'mse': 0.0216009126984127}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Population', 'value': 998.0, 'split_index': 5, 'mse': 0.004689900000000001}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.53565, 'split_index': 1, 'mse': 0.0011417500000000026}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.6891499999999997, 'split_index': 3, 'mse': 0.00023716666666666672}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.2972, 'split_index': 2, 'mse': 2.0166666666667108e-05}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.8523, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.1625, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 1.98875, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'Latitude', 'value': 37.845, 'split_index': 4, 'mse': 0.03390314285714287}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 3.24625, 'split_index': 2, 'mse': 8.900000000000016e-05}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 2.9234999999999998, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 3.72215, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 5.40013075647404, 'split_index': 2, 'mse': 0.0133481666666667}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 3.17275, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveRooms', 'value': 5.393969916733816, 'split_index': 4, 'mse': 0.11779091111111109}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'AveBedrms', 'value': 0.9707789730678263, 'split_index': 1, 'mse': 0.010524499999999996}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 3.4055999999999997, 'split_index': 1, 'mse': 0.0012326666666666625}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 3.864, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 8.3133, 'split_index': 4, 'mse': 0.004089749999999999}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 6.45025, 'split_index': 2, 'mse': 0.0005221250000000018}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 4.74465, 'split_index': 1, 'mse': 0.0}
# MedInc
# HouseAge
# AveRooms
# AveBedrms
# Population
# AveOccup
# Latitude
# Longitude
# {'feature': 'MedInc', 'value': 7.779399999999999, 'split_index': 1, 'mse': 0.0}
# 3.422

# %% [markdown]
# ### E) ANN- Implementation single Neuron(Perceptron) from scratch

# %%
class Neurone:
    def __init__(self,examples,n_feats=3):
        np.random.seed(100)
        self.examples = examples
        self.n_feats = n_feats
        self.W = np.random.normal(0,1,self.n_feats+1)
        self.train()
    
    def train(self,learning_rate=0.1, batch_size=10, epochs=5000):
        no_batch = len(self.examples) % batch_size
        for i in range(len(self.examples)):
            self.examples[i]['feats'].append(1)

        for i in range(epochs):
            # Error = []
            Error = 0
            for batch in range(no_batch):
                grad = np.zeros(self.n_feats + 1,float) 
                minibatch = self.examples[batch * batch_size:(batch+1) * batch_size]  
                for e in minibatch:
                    raw = np.sum([e['feats'][i] * self.W[i] for i in range(self.n_feats + 1)])
                    pred = 1/(1 + np.exp(-1 * raw))
                    error = (pred - e['label'])
                    Error += np.abs(error) 
                    for j in range(4):
                        grad[j] += error * e['feats'][j]
                
                grad = grad/batch_size
                self.W = self.W - learning_rate * grad
            Error = Error/len(self.examples)
            if i % 100 == 0:
                print(np.mean(Error))
                # print(self.W)

    def predict(self, features):
        features.append(1)
        val = np.sum(np.array(features).reshape(1,len(self.W)) * self.W)
        return np.round(1/(1+np.exp(-(val))),5)

data = [{'feats':[0.1,0.11,0.3],'label':0},{'feats':[0.19,0.51,0.39],'label':1},{'feats':[0.01,0.18,0.23],'label':0},{'feats':[0.31,0.411,0.43],'label':1},{'feats':[0.51,0.611,0.35],'label':1},{'feats':[0.11,0.211,0.035],'label':0}]
N = Neurone(data)
N.train()
# Out:
# 0.5134133891414737
# 0.4724156898328847
# 0.43997363641644077
# 0.4110592570734297
# 0.38485707393166235
# 0.36112466206864835
# 0.3396586274471911
# 0.3202472460397928
# 0.30267930456762665
# 0.28675403837155194
# 0.2722868078050443
# 0.2591114069272577
# 0.2470802738534982
# 0.23606353222275936
# 0.2259474625470025
# 0.21663276508495125
# 0.2080328201376792
# 0.2000720541442754
# 0.1926844612088564
# 0.185812295713822
# 0.17940493304304786
# 0.1734178860525758
# 0.16781196094487874
# 0.1625525352615869
# 0.15760894138312717
# 0.15295394037198237
# 0.14856327273824943
# 0.14441527447762775
# 0.1404905483972728
# 0.13677168224301406
# 0.1332430064531595
# 0.12989038549284423
# 0.12670103768308044
# 0.12366337924930065
# 0.1207668889951889
# 0.1180019905779459
# 0.11535994983799676
# 0.11283278503457701
# 0.11041318817154451
# 0.108094455876098
# 0.10587042852604552
# 0.10373543651650753
# 0.10168425272084365
# 0.09971205033843178
# 0.0978143654380806
# 0.09598706360392584
# 0.09422631017364748
# 0.09252854362921599
# 0.09089045176017722
# 0.08930895027042794
# 0.08778116354291067
# 0.08630440731386357
# 0.08487617304014583
# 0.08349411377057192
# 0.08215603135578396
# 0.08085986485155482
# 0.07960367998802163
# 0.0783856595926121
# 0.07720409486766797
# 0.07605737743529754
# 0.07494399207203417
# 0.07386251006464738
# 0.07281158312613274
# 0.0717899378176293
# 0.07079637042792276
# 0.06982974226738843
# 0.0688889753378039
# 0.06797304834350552
# 0.06708099301292848
# 0.06621189070273932
# 0.06536486925957023
# 0.06453910011685536
# 0.063733795606486
# 0.06294820646697587
# 0.062181619531584936
# 0.06143335558142631
# 0.060702767349985226
# 0.05998923766674019
# 0.059292177728705715
# 0.05861102548973116
# 0.05794524415830322
# 0.057294320795419386
# 0.05665776500484173
# 0.05603510770870779
# 0.05542590000207795
# 0.05482971208054666
# 0.054246132235536614
# 0.05367476591234435
# 0.05311523482641267
# 0.05256717613367167
# 0.05203024165113084
# 0.051504097124203
# 0.0509884215375272
# 0.05048290646630413
# 0.04998725546539415
# 0.04950118349363719
# 0.04902441637104852
# 0.04855669026671879
# 0.048097751215413355
# 0.04764735466100997

# %%
feature = [[0.72,0.81,0.71],[0.12,0.11,0.41]]
assert N.predict(feature[0]) == 0.99999
assert N.predict(feature[1]) == 0.14156
